# %%
import pandas as pd 
import seaborn as sns 
import numpy as np
import matplotlib.pyplot as plt 
sns.set(color_codes=True)
import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("car_data.csv")

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## <font color ="blue"> Exploratory Data Analysis: </font>

# %%
sns.scatterplot(df['Kms_Driven'],df['Selling_Price'],data=df)
# Out:
# <AxesSubplot:xlabel='Kms_Driven', ylabel='Selling_Price'>

# %%
sns.pairplot(data=df)

# %%
d=df.groupby('Year')['Car_Name']
d

# %%
print(df['Seller_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   299.000000     299.000000     299.000000     299.000000  299.000000
# mean   2013.615385       4.589632       7.541037   36916.752508    0.043478
# std       2.896868       4.984240       8.567887   39015.170352    0.248720
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.850000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.510000       6.100000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.840000   48883.500000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df['years_old']=df['Year'].apply(lambda x : 2020 - x)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  years_old
# 0      Dealer       Manual      0          6
# 1      Dealer       Manual      0          7
# 2      Dealer       Manual      0          3
# 3      Dealer       Manual      0          9
# 4      Dealer       Manual      0          6

# %%
df.drop(['Year','Car_Name'],inplace=True,axis=1)

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  years_old
# 0       Manual      0          6
# 1       Manual      0          7
# 2       Manual      0          3
# 3       Manual      0          9
# 4       Manual      0          6

# %%
final_data= pd.get_dummies(df,drop_first=True)

# %%
final_data.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  years_old  \
# 0           3.35           5.59       27000      0          6
# 1           4.75           9.54       43000      0          7
# 2           7.25           9.85        6900      0          3
# 3           2.85           4.15        5200      0          9
# 4           4.60           6.87       42450      0          6
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
correlation_matrix=final_data.corr()
top_corr_features=correlation_matrix.index
plt.figure(figsize=(20,20))
g = sns.heatmap(final_data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# ### spliting data into x_train and y_train:

# %%
X=final_data.iloc[:,1:]
y=final_data.iloc[:,0]

# %% [markdown]
# #### Feature Importance :
# - find the top features

# %%
from sklearn.ensemble import RandomForestRegressor
tree = RandomForestRegressor()
tree.fit(X,y)
# Out:
# RandomForestRegressor()

# %%
print(tree.feature_importances_)
# Out:
# [8.76206610e-01 2.53271740e-02 6.45424486e-05 8.64075825e-02
#  2.92932864e-03 3.11970231e-03 3.51781404e-03 2.42724568e-03]

# %%
list(X.columns.values)
# Out:
# ['Present_Price',
#  'Kms_Driven',
#  'Owner',
#  'years_old',
#  'Fuel_Type_Diesel',
#  'Fuel_Type_Petrol',
#  'Seller_Type_Individual',
#  'Transmission_Manual']

# %%
features_df=pd.DataFrame({'features':list(X.columns.values) , 'importance':tree.feature_importances_})
features_df
# Out:
#                  features  importance
# 0           Present_Price    0.876207
# 1              Kms_Driven    0.025327
# 2                   Owner    0.000065
# 3               years_old    0.086408
# 4        Fuel_Type_Diesel    0.002929
# 5        Fuel_Type_Petrol    0.003120
# 6  Seller_Type_Individual    0.003518
# 7     Transmission_Manual    0.002427

# %%
features_df=features_df.sort_values(by='importance',ascending=False)

# %%
f, axes = plt.subplots(figsize=(15,5)) 
sns.barplot(x='features',y='importance', data=features_df)
plt.xticks(rotation=90)
plt.tight_layout()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.1)

# %%
np.array(x_train)
# Out:
# array([[7.0000e+00, 4.0026e+04, 0.0000e+00, ..., 1.0000e+00, 0.0000e+00,
#         1.0000e+00],
#        [6.9500e+00, 4.5000e+04, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         1.0000e+00],
#        [5.8700e+00, 5.5138e+04, 0.0000e+00, ..., 1.0000e+00, 0.0000e+00,
#         1.0000e+00],
#        ...,
#        [9.4000e+00, 3.2322e+04, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         1.0000e+00],
#        [1.3700e+01, 7.5000e+04, 0.0000e+00, ..., 1.0000e+00, 0.0000e+00,
#         1.0000e+00],
#        [1.7800e+00, 4.0000e+03, 0.0000e+00, ..., 1.0000e+00, 1.0000e+00,
#         1.0000e+00]])

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()

x_train = scalar.fit_transform(x_train)
x_train
# Out:
# array([[ 0.12015697, -0.82482688, -0.1860521 , ...,  0.48952154,
#         -0.76312053,  0.38674623],
#        [-0.19121241,  0.15105676, -0.1860521 , ...,  0.48952154,
#         -0.76312053,  0.38674623],
#        [-0.73061065, -0.17423779, -0.1860521 , ...,  0.48952154,
#          1.31040899,  0.38674623],
#        ...,
#        [ 0.72206059,  0.08409613, -0.1860521 , ...,  0.48952154,
#         -0.76312053,  0.38674623],
#        [-0.02684642, -0.07414716, -0.1860521 , ...,  0.48952154,
#         -0.76312053,  0.38674623],
#        [-0.81510866, -0.0491245 , -0.1860521 , ...,  0.48952154,
#          1.31040899,  0.38674623]])

# %% [markdown]
# # <font color="green">Decision Tree Algorithm:</font>

# %% [markdown]
# #### <font color="blue">selecting the splitting criterion:</font>
# - Attribute selection measure(ASM)is a heuristic for selecting the splitting criterion that breaks the dataset into smaller subsets.
# - some of the splitting ***criterion*** are as follows :
#
# 1. **Information Gain** : ID3(Iterative Dichotomiser) decision tree algorithm uses information gain.
# 2. **Gain Ratio** : C4.5, an improvement of ID3, uses an extension to information gain known as the gain ratio.
# 3. **Gini index**: CART(classification and Regression Tree) uses the Gini index to split the data.

# %%
x_train.shape
x_train
# Out:
#      Present_Price  Kms_Driven  Owner  years_old  Fuel_Type_Diesel  \
# 137          0.787       16000      0          7                 0
# 63          35.960       47000      0          5                 1
# 34           8.060       45000      0          6                 1
# 76          14.680       72000      0          7                 0
# 182          0.580       30000      0          7                 0
# ..             ...         ...    ...        ...               ...
# 153          0.990       45000      0          7                 0
# 264          7.000       40026      0          5                 0
# 23           3.460       45280      0          6                 0
# 195          0.320       35000      0          5                 0
# 297          5.900       60000      0          5                 0
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 137                 1                       1                    1
# ...

# %% [markdown]
# # Training

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
model = {}
Mean_squared_error = {}
Mean_absolute_error= {}
R2_score = {}

from sklearn.ensemble import RandomForestRegressor
model['Random Forest'] = RandomForestRegressor()

from sklearn.linear_model import LinearRegression
model['Linear regression'] = LinearRegression()


from xgboost import XGBRegressor
model['xgboost'] = XGBRegressor()


from lightgbm import LGBMRegressor
model['lightgbm'] = LGBMRegressor()


for key in model.keys():
    model[key].fit(x_train,y_train)
    predictions = model[key].predict(x_test)
    Mean_squared_error[key]=mean_squared_error(y_test,predictions)
    R2_score[key]=r2_score(y_test,predictions)
    Mean_absolute_error[key]=mean_absolute_error(y_test,predictions)

# %%
Mean_squared_error
# Out:
# {'Random Forest': 0.6640362900000064,
#  'Linear regression': 2.006833969263369,
#  'xgboost': 0.4479525423470757,
#  'lightgbm': 1.6713762997460166}

# %%
R2_score
# Out:
# {'Random Forest': 0.974553392654893,
#  'Linear regression': 0.9230958958242074,
#  'xgboost': 0.9828339615981706,
#  'lightgbm': 0.9359510058922318}

# %% [markdown]
# - Xgboost is performing nicely.

# %%
regression = XGBRegressor()
regression.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %% [markdown]
# # New data Prediction:

# %%
np.array(x_test)[0]
# Out:
# array([6.05e+00, 4.70e+04, 0.00e+00, 7.00e+00, 0.00e+00, 1.00e+00,
#        0.00e+00, 1.00e+00])

# %%
regression.predict(np.array(x_test)[0].reshape(1,-1))
# Out:
# array([3.8731678], dtype=float32)

# %% [markdown]
# ## Pickling the model file for Deployment :

# %%
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickled_model = pickle.load(open('regmodel.pkl','rb'))

# %%
pickled_model.predict(np.array(x_test)[0].reshape(1,-1))
# Out:
# array([3.8731678], dtype=float32)
